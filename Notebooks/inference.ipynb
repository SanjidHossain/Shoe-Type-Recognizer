# %%
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

# %%
from fastai.vision.all import *

# %%
version = 4
img_path = 'test image'
model_path = f'models/shoes-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** Army boot

# %%
img = Image.open(f'{img_path}/image-01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Army boots',
#  tensor(0),
#  tensor([9.8569e-01, 1.0979e-07, 3.8865e-05, 5.9488e-08, 1.8321e-07, 1.0918e-06,
#          1.2080e-05, 1.4198e-07, 2.0667e-07, 2.9475e-06, 6.6081e-08, 2.7047e-09,
#          1.8052e-06, 8.2478e-06, 5.8710e-05, 1.8010e-03, 1.2073e-02, 4.8756e-05,
#          5.2674e-08, 3.4163e-06, 1.2920e-05, 2.4643e-06, 5.4494e-08, 3.4297e-06,
# ...

# %% [markdown]
# # Inference 2
#
# **Target:** chelsea boot

# %%
img = Image.open(f'{img_path}/image-02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Chelsea Boot',
#  tensor(4),
#  tensor([4.4755e-09, 1.8765e-09, 3.9063e-09, 6.3520e-09, 9.9994e-01, 1.8482e-08,
#          5.0804e-07, 1.3008e-08, 9.9453e-09, 6.4261e-06, 4.4618e-08, 1.3377e-08,
#          5.8179e-09, 5.9827e-08, 5.3026e-08, 3.9620e-09, 7.3838e-08, 2.0329e-10,
#          8.3465e-09, 7.3478e-08, 2.9103e-07, 5.8483e-08, 2.8244e-07, 1.4644e-07,
# ...

# %% [markdown]
# # Inference 3
#
# **Target:** chuck taylor

# %%
img = Image.open(f'{img_path}/image-03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Chuck Taylor',
#  tensor(5),
#  tensor([4.4326e-08, 3.6161e-08, 8.6038e-06, 1.3838e-07, 4.8729e-08, 9.9985e-01,
#          1.8724e-09, 1.1415e-07, 2.7170e-07, 3.5033e-09, 1.5496e-08, 2.8851e-09,
#          6.6209e-09, 2.1988e-08, 1.7393e-07, 1.2819e-04, 3.1869e-08, 1.1082e-06,
#          9.9592e-09, 3.3159e-07, 1.9124e-08, 1.5079e-08, 1.0103e-06, 5.6806e-08,
# ...

# %% [markdown]
# # Inference 4
#
# **Target:** Flip flop

# %%
img = Image.open(f'{img_path}/image-04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/image-04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Flip flop',
#  tensor(12),
#  tensor([1.8264e-11, 2.7230e-07, 4.4116e-09, 2.3095e-13, 5.2940e-11, 8.7148e-11,
#          1.6655e-07, 9.4577e-10, 7.5522e-11, 3.1045e-11, 1.7654e-11, 9.8896e-14,
#          9.9998e-01, 5.1508e-11, 1.5729e-10, 5.8649e-13, 3.4987e-11, 3.4169e-10,
#          3.6530e-08, 1.1819e-10, 1.5994e-12, 8.7982e-10, 1.6880e-10, 5.3349e-10,
# ...

# %% [markdown]
# # Inference 5
#
# **Target:** Hiking boot

# %%
img = Image.open(f'{img_path}/image-05.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/image-05.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Hiking boots',
#  tensor(16),
#  tensor([1.1101e-03, 3.9588e-06, 2.0206e-04, 2.0352e-06, 9.0802e-06, 5.3442e-05,
#          1.1506e-03, 1.1530e-05, 1.4779e-06, 1.6361e-05, 9.8307e-06, 4.8395e-07,
#          5.4959e-04, 4.0941e-06, 1.7947e-04, 4.4497e-05, 9.9205e-01, 6.7931e-06,
#          1.6355e-04, 7.4207e-06, 9.1406e-05, 5.1082e-04, 1.5941e-06, 1.9808e-06,
# ...

# %% [markdown]
# # Inference 6
#
# **Target:** old skool

# %%
img = Image.open(f'{img_path}/image-06.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-06.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Old skool',
#  tensor(26),
#  tensor([3.5940e-06, 1.0261e-04, 6.7876e-06, 1.4782e-02, 8.7190e-05, 4.3950e-02,
#          1.8083e-06, 1.3430e-06, 8.2857e-05, 7.9203e-07, 4.2862e-04, 8.0268e-05,
#          1.4844e-05, 4.4334e-06, 3.3897e-07, 3.2452e-03, 1.1366e-04, 4.1962e-06,
#          5.9285e-06, 1.3571e-06, 3.6888e-06, 1.9960e-06, 2.2115e-01, 3.0663e-05,
# ...

# %% [markdown]
# # Inference 7
#
# **Target:** mary jane

# %%
img = Image.open(f'{img_path}/image-07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mary Jane platforms',
#  tensor(23),
#  tensor([7.3666e-13, 2.7692e-14, 3.4203e-14, 3.8137e-15, 7.4895e-14, 6.6162e-15,
#          1.9403e-14, 1.4794e-13, 6.3117e-13, 1.8622e-15, 5.7601e-16, 8.9448e-16,
#          8.2073e-13, 1.6027e-13, 9.3840e-12, 2.6282e-11, 6.3376e-13, 7.6966e-11,
#          2.1898e-15, 5.4987e-14, 3.3379e-12, 1.1650e-13, 1.1178e-11, 1.0000e+00,
# ...

# %% [markdown]
# # Inference 8
#
# **Target:** platform heel

# %%
img = Image.open(f'{img_path}/image-08.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-08.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Platform heels',
#  tensor(28),
#  tensor([3.1528e-06, 7.0742e-07, 3.3922e-07, 2.1671e-06, 1.0064e-07, 6.0994e-06,
#          2.6180e-07, 1.6331e-03, 3.0767e-04, 3.2416e-06, 3.3790e-07, 3.4201e-05,
#          5.3639e-06, 2.6446e-07, 3.6262e-02, 4.6371e-07, 4.6894e-06, 4.1064e-06,
#          9.0120e-06, 5.4283e-06, 1.9010e-04, 2.6772e-05, 1.9371e-06, 4.3580e-04,
# ...

# %% [markdown]
# # Inference 9
#
# **Target:** wedges

# %%
img = Image.open(f'{img_path}/image-09.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=100x128>

# %%
model.predict(f'{img_path}/image-09.jpg')

# %% [markdown]
# # Inference 10
#
# **Target:** Sandals

# %%
img = Image.open(f'{img_path}/image-10.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/image-10.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Sandal',
#  tensor(30),
#  tensor([5.5803e-11, 5.3377e-10, 1.1514e-10, 1.0738e-09, 6.6830e-09, 3.1606e-12,
#          8.0193e-08, 1.2627e-08, 3.2935e-10, 1.1805e-08, 1.1515e-09, 1.7534e-06,
#          1.2185e-07, 5.6078e-08, 5.8078e-10, 6.6534e-10, 4.0208e-08, 3.1449e-10,
#          2.4416e-08, 1.4337e-10, 1.9650e-10, 4.1074e-10, 4.5303e-08, 5.9007e-09,
# ...
